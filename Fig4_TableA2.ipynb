# %%
from pathlib import Path

import numpy as np
import scipy as sci
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

from glacierData import glacierData
from data import load_rgi, load_mb
from utils import detrend

# %%
gd = glacierData()
gd.calc_response_time()
gd.calc_diseq()
d = gd.rgi
# Out:
# /Users/drotto/src/USGS/glacier-diseq/pub/thickness.py:9: UserWarning: Unpickling a shapely <2.0 geometry object. Please save the pickle again; shapely 2.1 will not have this compatibility.
#   f_geom = pickle.load(f)

# %%
rgi = load_rgi()

# %%
mb = load_mb()
# Out:
# /Users/drotto/src/USGS/glacier-diseq/pub/data.py:52: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   wgms = pd.read_csv(fp, encoding='iso-8859-1')
# /Users/drotto/micromamba/envs/glacier-diseq/lib/python3.8/site-packages/openpyxl/worksheet/_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /Users/drotto/micromamba/envs/glacier-diseq/lib/python3.8/site-packages/openpyxl/worksheet/_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /Users/drotto/src/USGS/glacier-diseq/pub/data.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   g.iloc[0]['swe'] = ba

# %%
m = mb.loc[mb.BALANCE_CODE == 'BA', :].copy()

dbdz_concat = {}
obs =[]
for k, g in m.groupby('Name'):
    # group points
    base = 150
    g['eband'] = (g['POINT_ELEVATION']/base).round() * base

    # screen bad data
    mask = [True]  # default state, filter nothing
    if k == 'Taku Glacier':
        mask = (g.point_swe_m < 4) & (g.point_swe_m > 0)
        continue
    if k == 'Gilkey Glacier':
        pass
        
    if k == 'East Yakutat Glacier':
        
        mask = (g.POINT_ELEVATION > 100)
    if k == 'Wolverine Glacier':
        mask = (g.POINT_ELEVATION > 500)
    if k == 'Kahiltna Glacier':
        mask = (g.POINT_ELEVATION < 1500)
    if k == 'Eklutna Glacier':
        mask = (g.POINT_ELEVATION > 1100)
    if k == 'Mendenhall Glacier':
        mask = (g.POINT_ELEVATION > 100)
    if k == 'Lemon Creek Glacier':
        #pass
        mask = (~g.omit)
    if k == 'Columbia Glacier':
        # pass 
        mask = (g.point_swe_m < 2)
    if k == 'Exit Glacier':
        # pass 
        mask = (g.point_swe_m < 2)
    mask = (g.Name == k) & (mask)


    # plot eband over time
    g = g.sort_values('YEAR')
    fig, ax = plt.subplots(1,1)
    norm = mpl.colors.Normalize(vmin=g.eband.min(), vmax=g.eband.max())
    for eband, gg in g.loc[mask].groupby('eband'):
        ax.plot(gg.YEAR, gg.point_swe_m, c=mpl.colormaps['viridis'](norm(eband)), marker='o', alpha=0.75, label=eband)
    ax.set_title(f"{k}, with points omitted")
    ax.legend()

    # viz balance profiles
    fig, ax = plt.subplots(1, 1)
    g = g.sort_values(by='POINT_ELEVATION')
    norm = mpl.colors.Normalize(vmin=g.YEAR.min(), vmax=g.YEAR.max())
    for year, gg in g.groupby('YEAR'):
        gg_omit = gg.loc[~mask]
        gg = gg.loc[mask]
        ax.plot(gg_omit['point_swe_m'], gg_omit['POINT_ELEVATION'], c=mpl.colormaps['autumn'](norm(year)), marker='o', alpha=0.75)
        ax.plot(gg['point_swe_m'], gg['POINT_ELEVATION'], c=mpl.colormaps['winter'](norm(year)), marker='o', alpha=0.75)
        
    # mask out values from analysis
    g = g.loc[mask]
    
    ######################
    # calculate the dbdz
    ######################
    x = g['POINT_ELEVATION']
    y = g['point_swe_m']
    if k not in ['Kahiltna Glacier']:
        y = detrend(y, g['YEAR'])
    ols = sci.stats.linregress(x, y)
    yhat = ols.intercept + x * ols.slope
    print("Initial check (Detrended):", k, f"{ols.slope*1000:.2f}")
    dbdz = {"slope": ols.slope, "intercept": ols.intercept}
    print(dbdz)

    ######################
    # do dbdz by year, aka assuming each year is NOT noise around the same dbdz
    # silly way to avoid detrending
    ######################
    dbdz_yr = {}
    for year, gg in g.groupby('YEAR'):
        x = gg['POINT_ELEVATION']
        y = gg['point_swe_m']
        ols = sci.stats.linregress(x, y)
        if ~np.isnan(ols.slope):
            dbdz_yr[year] = ols.slope
    print(k, f"by year: {np.mean(list(dbdz_yr.values()))*1000:.2f}")


    # check dbdz using eband
    # detrend by eband
    concat = []
    if k not in ['Kahiltna Glacier']:
        for e, gg in g.groupby('eband'):
            if len(gg) >= 3:
                try:
                    swe_mean = gg['point_swe_m'].mean()
                    gg['point_swe_m'] = detrend(gg['point_swe_m'], gg['YEAR']) + swe_mean
                except:
                    print(f"Detrend failed for {k} {e} m, nobs = {len(gg)}")
            concat.append(gg)
        g = pd.concat(concat, ignore_index=True)
    x = g['POINT_ELEVATION']
    y = g['point_swe_m']
    ols = sci.stats.linregress(x, y)
    yhat = ols.intercept + x * ols.slope
    print("Dbdz using eband (dropping <3 obs ebands)", k, f"{ols.slope*1000:.2f}, {ols.intercept:.2f} \n")
    #print(g.loc[:, ['POINT_ELEVATION', 'point_swe_m', 'Name', 'nobs']])

    # group by eband
    counts = g.groupby('eband')['point_swe_m'].count()
    ebands = g.groupby('eband').mean(numeric_only=True)
    ebands['Name'] = k
    ebands['nobs'] = counts

    # plot eband grouped balance profile
    ax.plot(ebands['point_swe_m'], ebands['POINT_ELEVATION']
            , c='black', marker='o', alpha=1, ls='--', lw=3)
    x = np.arange(g['POINT_ELEVATION'].min(), g['POINT_ELEVATION'].max(), 10)
    ax.plot(ols.intercept + ols.slope * x, x, lw=3, c='red')
    ax.set_title(k)
    ax.legend()
    
    # ok this is kinda shitty. I'm just going to replace the intercept for the initial fit with the one from the eband fit. The slope from the initial fit is the one that is important, but we want the line to go through the points on the plot. 
    dbdz['intercept'] = ols.intercept 
    dbdz['ebands'] = ebands.copy()
    dbdz['points'] = g.copy()
    obs.append(g)
    dbdz_concat[k] = dbdz
obs = pd.concat(obs)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Initial check (Detrended): Black Rapids Glacier 6.37
# {'slope': 0.006373673818896578, 'intercept': -10.14111173022197}
# Black Rapids Glacier by year: 7.24
# Dbdz using eband (dropping <3 obs ebands) Black Rapids Glacier 6.40, -11.98
#
# Initial check (Detrended): Columbia Glacier 6.42
# {'slope': 0.006421512683940918, 'intercept': -4.669791618632194}
# Columbia Glacier by year: 5.91
# Detrend failed for Columbia Glacier 150.0 m, nobs = 5
# Detrend failed for Columbia Glacier 900.0 m, nobs = 3
# Dbdz using eband (dropping <3 obs ebands) Columbia Glacier 6.53, -6.82
#
# Initial check (Detrended): East Yakutat Glacier 6.46
# {'slope': 0.006464582894564278, 'intercept': -2.771930618599022}
# East Yakutat Glacier by year: 6.41
# Dbdz using eband (dropping <3 obs ebands) East Yakutat Glacier 6.48, -6.39
#
# Initial check (Detrended): Eklutna Glacier 6.88
# {'slope': 0.006878862756456919, 'intercept': -9.532818415808526}
# Eklutna Glacier by year: 6.90
# Dbdz using eband (dropping <3 obs ebands) Eklutna Glacier 6.74, -11.77
#
# Initial check (Detrended): Exit Glacier 7.81
# {'slope': 0.007812158907462319, 'intercept': -8.67906441622475}
# Exit Glacier by year: 8.24
# Dbdz using eband (dropping <3 obs ebands) Exit Glacier 7.72, -8.91
# /Users/drotto/micromamba/envs/glacier-diseq/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:182: RuntimeWarning: invalid value encountered in scalar divide
#   slope = ssxym / ssxm
# /Users/drotto/micromamba/envs/glacier-diseq/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:196: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/drotto/micromamba/envs/glacier-diseq/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:199: RuntimeWarning: invalid value encountered in scalar divide
#   slope_stderr = np.sqrt((1 - r**2) * ssym / ssxm / df)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Initial check (Detrended): Gilkey Glacier 6.40
# {'slope': 0.006398977174269899, 'intercept': -7.1207796665351415}
# Gilkey Glacier by year: 4.52
# Dbdz using eband (dropping <3 obs ebands) Gilkey Glacier 6.42, -10.55
#
# Initial check (Detrended): Gulkana Glacier 7.77
# {'slope': 0.0077734001841338, 'intercept': -12.897904254578009}
# Gulkana Glacier by year: 7.94
# Dbdz using eband (dropping <3 obs ebands) Gulkana Glacier 7.56, -13.83
#
# Initial check (Detrended): Kahiltna Glacier 3.25
# {'slope': 0.003251660665208156, 'intercept': -7.446981437631335}
# Kahiltna Glacier by year: 3.25
# Dbdz using eband (dropping <3 obs ebands) Kahiltna Glacier 3.25, -7.45
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /Users/drotto/micromamba/envs/glacier-diseq/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:182: RuntimeWarning: invalid value encountered in scalar divide
#   slope = ssxym / ssxm
# /Users/drotto/micromamba/envs/glacier-diseq/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:196: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/drotto/micromamba/envs/glacier-diseq/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:199: RuntimeWarning: invalid value encountered in scalar divide
#   slope_stderr = np.sqrt((1 - r**2) * ssym / ssxm / df)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /var/folders/bb/wssqxcxj4tgg0s9fdw74731m0000gn/T/ipykernel_43839/360455953.py:43: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(1,1)
# /Users/drotto/micromamba/envs/glacier-diseq/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:182: RuntimeWarning: invalid value encountered in scalar divide
#   slope = ssxym / ssxm
# /Users/drotto/micromamba/envs/glacier-diseq/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:196: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/drotto/micromamba/envs/glacier-diseq/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:199: RuntimeWarning: invalid value encountered in scalar divide
#   slope_stderr = np.sqrt((1 - r**2) * ssym / ssxm / df)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Initial check (Detrended): Lemon Creek Glacier 10.48
# {'slope': 0.010479229140342706, 'intercept': -11.313375779914132}
# Lemon Creek Glacier by year: 10.43
# Dbdz using eband (dropping <3 obs ebands) Lemon Creek Glacier 10.47, -12.32
#
# Initial check (Detrended): Mendenhall Glacier 9.90
# {'slope': 0.009899350657488233, 'intercept': -8.733679272913681}
# Mendenhall Glacier by year: 7.80
# Dbdz using eband (dropping <3 obs ebands) Mendenhall Glacier 10.06, -12.41
#
# Initial check (Detrended): Wolverine Glacier 7.47
# {'slope': 0.007467100689704602, 'intercept': -7.7232105149310675}
# Wolverine Glacier by year: 7.63
# Dbdz using eband (dropping <3 obs ebands) Wolverine Glacier 7.29, -8.68

# %%
colors = plt.cm.tab20(np.linspace(0, 1, 20))
markers = ['o', '^', 's', 'X', '<',  'D', '*', '>', 'P', 'p', 'v', 'h']

fig, ax = plt.subplots(1, 1, dpi=200, figsize=(5, 4), layout='constrained')
for i, (k, dbdz) in enumerate(dbdz_concat.items()):
    # manual adjustments
    if k == 'Exit Glacier':
        dbdz['intercept'] += 0.15
        dbdz['ebands']['point_swe_m'] += 0.15
        pass
    
    g = dbdz['ebands'].copy()

    print(k)
    print(dbdz['slope'], dbdz['intercept'])
    print(g.loc[:, ['POINT_ELEVATION', 'point_swe_m', 'nobs']])
    rgi_row = rgi.loc[(rgi.Name == k), :].iloc[0]
    xmin = g['POINT_ELEVATION'].min()
    xmax = g['POINT_ELEVATION'].max()
    x = np.linspace(xmin, xmax, 3)
    yhat = dbdz['intercept'] + x * dbdz['slope']
    
    ax.plot(
        yhat,
        x,
        lw=3,
        color=colors[i],
#        zorder=2.01
    )
    ax.plot(
        g['point_swe_m'],
        g['POINT_ELEVATION'],
        marker=markers[i],
        markersize=6,
        fillstyle='full',
        markeredgecolor='black',
        markeredgewidth=1,
        color=colors[i],
        linewidth=1,
        ls='',
        label=k,
        zorder=2.01
    )

# McCall glacier
slope_a = 0.00172  # m swe / m
slope_b = 0.00201  # m swe / m
slope = (slope_a + slope_b)/2
y0 = 1400
y1 = 2500
dy = 2500-1400
x0 = (-1.4 + -1.85)/2
x1 = x0 + dy*slope
ax.plot([x0, x1], [y0, y1], label='McCall Glacier', lw=3, color=colors[-1])

ax.axline(
    xy1=(-10, 0),
    slope=1 / 0.0065,
    color='black',
    ls='--',
    lw=4,
    zorder=2.00,
)
ax.set_xlim(-10, 4)
ax.set_ylim(0, 2625)
ax.set_xlabel('Mass balance [m yr$^{-1}$]')
ax.set_ylabel('Elevation [m]')
ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(250))
ax.grid(which='major', axis='both', ls='-', lw=0.5)
ax.grid(which='minor', axis='both', ls='-', lw=0.5, alpha=0.25)
ax.tick_params(axis='both', which='both', direction='in', length=3)
ax.tick_params(axis='both', which='major', length=6, width=1)
ax.legend(fontsize='x-small')

plt.savefig(Path('dbdz_scatterplot.png'))
# Out:
# Black Rapids Glacier
# 0.006373673818896578 -11.981510117217956
#         POINT_ELEVATION  point_swe_m  nobs
# eband
# 900.0        917.076923    -6.006923    13
# 1050.0      1113.444444    -4.272222     9
# 1200.0      1180.733333    -4.060200    15
# 1350.0      1333.058824    -3.780000    17
# 1500.0      1501.000000    -2.628700    60
# 1650.0      1707.720000    -1.109620    50
# 1800.0      1817.750000    -0.682167    12
# 1950.0      1922.303571     0.571446    56
# 2250.0      2227.666667     2.503333     3
# Columbia Glacier
# 0.006421512683940918 -6.8238142832775415
#         POINT_ELEVATION  point_swe_m  nobs
# eband
# 150.0        180.600000    -7.000000     5
# 300.0        275.000000    -4.275000     2
# 450.0        499.000000    -4.200000     2
# 600.0        600.700000    -2.450000    10
# 750.0        736.714286    -1.155714     7
# 900.0        937.000000    -0.433333     3
# 1050.0      1105.333333     0.596667     3
# 1200.0      1154.500000     0.200000     2
# 1350.0      1373.000000     1.186667     3
# 1500.0      1464.000000     1.200000     1
# East Yakutat Glacier
# 0.006464582894564278 -6.38991211097383
#        POINT_ELEVATION  point_swe_m  nobs
# eband
# 150.0       166.400000    -5.580000    10
# 300.0       278.500000    -4.405000     2
# 450.0       442.421053    -3.363158    19
# 600.0       583.785714    -2.549286    14
# 750.0       676.500000    -2.785000     2
# Eklutna Glacier
# 0.006878862756456919 -11.772939561153537
#         POINT_ELEVATION  point_swe_m  nobs
# eband
# 1050.0      1122.400000    -5.102360     1
# 1200.0      1142.220000    -4.099599     7
# 1350.0      1380.675000    -2.271958    12
# 1500.0      1521.161333    -1.620133    15
# Exit Glacier
# 0.007812158907462319 -8.76348023001434
#         POINT_ELEVATION  point_swe_m  nobs
# eband
# 900.0        867.000000    -2.118143     7
# 1050.0      1109.615385    -0.120985    13
# 1200.0      1237.125000     0.729524     8
# 1350.0      1290.000000     1.187500     4
# Gilkey Glacier
# 0.006398977174269899 -10.554126587903294
#         POINT_ELEVATION  point_swe_m  nobs
# eband
# 300.0           236.422       -9.054     1
# 1050.0          997.692       -3.690     1
# 1350.0         1313.231       -2.494     3
# 1500.0         1502.991       -0.262     1
# Gulkana Glacier
# 0.0077734001841338 -13.829560254559933
#         POINT_ELEVATION  point_swe_m  nobs
# eband
# 1200.0      1266.000000    -4.407500     4
# 1350.0      1378.827586    -3.425862    58
# 1500.0      1500.235294    -3.007059    17
# 1650.0      1699.037037    -0.833704    54
# 1800.0      1853.480000     0.553800    50
# 1950.0      1926.300000     0.269000    20
# 2100.0      2030.000000     0.625556     9
# Kahiltna Glacier
# 0.003251660665208156 -7.446981437631335
#         POINT_ELEVATION  point_swe_m  nobs
# eband
# 750.0             790.8    -5.150000     1
# 900.0             897.3    -4.570000     1
# 1050.0           1030.8    -3.905000     2
# 1200.0           1211.6    -3.426667     3
# 1350.0           1353.3    -3.200000     2
# Lemon Creek Glacier
# 0.010479229140342706 -12.320068475379529
#         POINT_ELEVATION  point_swe_m  nobs
# eband
# 750.0        819.000000    -4.853333     3
# 900.0        905.222222    -2.744444     9
# 1050.0      1063.800000    -1.022000     5
# 1200.0      1185.260870     0.158696    23
# Mendenhall Glacier
# 0.009899350657488233 -12.407199854179021
#         POINT_ELEVATION  point_swe_m  nobs
# eband
# 150.0        121.737143   -12.659229     7
# 300.0        330.600000    -8.672000     5
# 450.0        441.445000    -9.087500     4
# 750.0        683.152857    -3.011843     7
# 1050.0      1011.835556    -1.683311     9
# 1200.0      1203.131667    -0.318333     6
# 1350.0      1354.054286     0.724286     7
# 1500.0      1574.311429     2.540000     7
# Wolverine Glacier
# 0.007467100689704602 -8.680041881903971
#         POINT_ELEVATION  point_swe_m  nobs
# eband
# 600.0        601.584906    -4.169811    53
# 1050.0      1064.241935    -1.231935    62
# 1200.0      1235.428571    -0.532857     7
# 1350.0      1319.362319     1.198696    69

# %%
# number of obs
nobs = obs.loc[~obs.Name.isin([''])].pivot_table(index='Name', values='point_swe_m', aggfunc=lambda x: x.count())

# number of years
nyears = obs.loc[~obs.Name.isin([''])].pivot_table(index='Name', values='YEAR', aggfunc=lambda x: x.nunique())

# dbdzs
# lazy unpack
slopes = {}
for k, v in dbdz_concat.items():
    slopes[k] = f"{v['slope']*1000:.2f}"
slopes = pd.Series(slopes)

# year range
yr_range = obs.loc[~obs.Name.isin([''])].pivot_table(index='Name', values='YEAR', aggfunc=lambda x: f"{int(x.min())}-{int(x.max())}")
yr_range.columns = ['Years evaluated']

obs_zrange = obs.loc[~obs.Name.isin([''])].pivot_table(index='Name', values='POINT_ELEVATION', aggfunc=lambda x: f"{int(x.min())}-{int(x.max())} ({int(x.max() - x.min())})")

rgi = rgi.sort_values(by='Name')
rgi_zrange = rgi.loc[rgi.Name.isin(obs_zrange.index)].apply(lambda x: f"{x['Zmin']}-{x['Zmax']} ({x['Zmax'] - x['Zmin']})", axis=1)
rgi_zrange.index = obs_zrange.index

d = d.sort_values(by='Name')
bt = d.loc[rgi.Name.isin(obs_zrange.index), 'bt']
#bt.index = obs_zarange.index

# %%
table = pd.concat([slopes, nobs, nyears, yr_range, obs_zrange, rgi_zrange], axis=1)
table.columns = ['dbdz [m km]', 'N obs', 'N years', 'Years evaluated', 'Elevations evaluated (dz)', 'Glacier elevation (dz)']
p = Path('dbdz_table.csv')
table.to_csv('dbdz_table.csv')
print(p.resolve())

table
# Out:
# /Users/drotto/src/USGS/glacier-diseq/pub/dbdz_table.csv
#                      dbdz [m km]  N obs  N years Years evaluated  \
# Black Rapids Glacier        6.37    235       45       1972-2016
# Columbia Glacier            6.42     38        3       1978-2011
# East Yakutat Glacier        6.46     47        3       2009-2011
# Eklutna Glacier             6.88     35        8       2008-2015
# Exit Glacier                7.81     32        7       2011-2017
# Gilkey Glacier              6.40      6        3       2012-2014
# Gulkana Glacier             7.77    212       54       1966-2019
# Kahiltna Glacier            3.25      9        1       2011-2011
# Lemon Creek Glacier        10.48     40        6       2014-2019
# Mendenhall Glacier          9.90     52       11       1997-2010
# Wolverine Glacier           7.47    191       54       1966-2019
#
#                      Elevations evaluated (dz) Glacier elevation (dz)
# Black Rapids Glacier           896-2228 (1332)        722-3081 (2359)
# Columbia Glacier               140-1464 (1324)          0-3693 (3693)
# East Yakutat Glacier             105-677 (572)         28-1669 (1641)
# Eklutna Glacier                1122-1543 (421)        543-2050 (1507)
# Exit Glacier                    867-1290 (423)        122-1604 (1482)
# Gilkey Glacier                 236-1502 (1266)        107-2359 (2252)
# Gulkana Glacier                1260-2031 (771)       1162-2438 (1276)
# Kahiltna Glacier                790-1396 (605)        264-5134 (4870)
# Lemon Creek Glacier             818-1238 (420)         676-1494 (818)
# Mendenhall Glacier             101-1574 (1473)         94-1966 (1872)
# Wolverine Glacier               545-1373 (828)        426-1636 (1210)
